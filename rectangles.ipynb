# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.patches import Rectangle

plt.gca().add_patch(Rectangle((0, 0), 1, 5,
             edgecolor = 'k',
             facecolor = 'gray',
             alpha = 1,
             fill=True, label = 'Train',
             lw=1))

plt.gca().add_patch(Rectangle((0, 4), 1, 1,
             edgecolor = 'k',
             facecolor = 'orange',
             alpha = 1,
             fill=True, label = 'Test',
             lw=1))
# plt.gca().add_patch(Rectangle((0, 0), 1, 3,
#              edgecolor = 'k',
#              facecolor = 'teal',
#              alpha = 1,
#              fill=True, label = 'Train',
#              lw=1))
# plt.gca().add_patch(Rectangle((0, 3), 1, 2,
#              edgecolor = 'k',
#              facecolor = 'pink',
#              alpha = 1,
#              fill=True, label = 'Validation',
#              lw=1))

plt.gca().add_patch(Rectangle((1.1, 0), 1, 3,
             edgecolor = 'k',
             facecolor = 'teal',
             alpha = 1,
             fill=True, label = 'Train',
             lw=1))
plt.gca().add_patch(Rectangle((1.1, 3), 1, 1,
             edgecolor = 'k',
             facecolor = 'pink',
             alpha = 1,
             fill=True, label = 'Validation',
             lw=1))
plt.gca().add_patch(Rectangle((2.2, 0), 1, 2,
             edgecolor = 'k',
             facecolor = 'teal',
             alpha = 1,
#              fill=True, label = 'Train',
             lw=1))
plt.gca().add_patch(Rectangle((2.2, 2), 1, 1,
             edgecolor = 'k',
             facecolor = 'pink',
             alpha = 1,
#              fill=True, label = 'Validation',
             lw=1))
plt.gca().add_patch(Rectangle((2.2, 3), 1, 1,
             edgecolor = 'k',
             facecolor = 'teal',
             alpha = 1,
#              fill=True, label = 'Train',
             lw=1))

plt.gca().add_patch(Rectangle((3.3, 0), 1, 1,
             edgecolor = 'k',
             facecolor = 'teal',
             alpha = 1,
#              fill=True, label = 'Train',
             lw=1))
plt.gca().add_patch(Rectangle((3.3, 1), 1, 1,
             edgecolor = 'k',
             facecolor = 'pink',
             alpha = 1,
#              fill=True, label = 'Validation',
             lw=1))
plt.gca().add_patch(Rectangle((3.3, 2), 1, 2,
             edgecolor = 'k',
             facecolor = 'teal',
             alpha = 1,
#              fill=True, label = 'Train',
             lw=1))

# plt.gca().add_patch(Rectangle((4.4, 0), 1, 1,
#              edgecolor = 'k',
#              facecolor = 'teal',
#              alpha = 1,
# #              fill=True, label = 'Train',
#              lw=1))
plt.gca().add_patch(Rectangle((4.4, 0), 1, 1,
             edgecolor = 'k',
             facecolor = 'pink',
             alpha = 1,
#              fill=True, label = 'Validation',
             lw=1))
plt.gca().add_patch(Rectangle((4.4, 1), 1, 3,
             edgecolor = 'k',
             facecolor = 'teal',
             alpha = 1,
#              fill=True, label = 'Train',
             lw=1))
# plt.gca().add_patch(Rectangle((1.1, 3), 1, 1,
#              edgecolor = 'k',
#              facecolor = 'teal',
#              alpha = 1,
# #              fill=True, label = '',
#              lw=1))
# plt.gca().add_patch(Rectangle((1.1, 0), 1, 5,
#              edgecolor = 'k',
#              facecolor = 'gray',
#              alpha = 1,
# #              fill=True, label = 'Train',
#              lw=1))
# plt.gca().add_patch(Rectangle((2.2, 0), 1, 5,
#              edgecolor = 'k',
#              facecolor = 'gray',
#              alpha = 1,
# #              fill=True, label = 'Train',
#              lw=1))
# plt.gca().add_patch(Rectangle((3.3, 0), 1, 5,
#              edgecolor = 'k',
#              facecolor = 'gray',
#              alpha = 1,
# #              fill=True, label = 'Train',
#              lw=1))
# plt.gca().add_patch(Rectangle((4.4, 0), 1, 5,
#              edgecolor = 'k',
#              facecolor = 'gray',
#              alpha = 1,
# #              fill=True, label = 'Train',
#              lw=1))


# plt.gca().add_patch(Rectangle((1.1, 3), 1, 1,
#              edgecolor = 'k',
#              facecolor = 'orange',
#              alpha = 1,
# #              fill=True, label = 'Test',
#              lw=1))
# plt.gca().add_patch(Rectangle((2.2, 2), 1, 1,
#              edgecolor = 'k',
#              facecolor = 'orange',
#              alpha = 1,
# #              fill=True, label = 'Test',
#              lw=1))
# plt.gca().add_patch(Rectangle((3.3, 1), 1, 1,
#              edgecolor = 'k',
#              facecolor = 'orange',
#              alpha = 1,
# #              fill=True, label = 'Test',
#              lw=1))
# plt.gca().add_patch(Rectangle((4.4, 0), 1, 1,
#              edgecolor = 'k',
#              facecolor = 'orange',
#              alpha = 1,
# #              fill=True, label = 'Test',
#              lw=1))

plt.xlim(0,5.5)
plt.ylim(0,5)
plt.xticks([]) 
plt.yticks([])
plt.legend()
# ax.add_patch(Rectangle((q25, 0), q75 - q25, 5000,
# #              edgecolor = 'pink',
#              facecolor = 'k',
#                        alpha = 0.25,
#              fill=True,
#                label = 'IQR',
#              lw=5))

# plt.xlim(0,5000)
plt.box(False)

# %%
plt.gca().add_patch(Rectangle((0, 0), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
             fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((0,1.1), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((0, 2.2), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((0, 3.3), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((0, 4.4), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))

plt.gca().add_patch(Rectangle((2, 1.1), 1, 3.2,
             edgecolor = 'k',
             facecolor = 'red',
             alpha = 1,
             fill=True, label = 'Theory',
             lw=1))
plt.plot(
    (1,2),
    (5.4,4.3),
    c = 'k',
    linewidth = 1
)
plt.plot(
    (1,2),
    (0,1.1),
    c = 'k',
    linewidth = 1
)




plt.gca().add_patch(Rectangle((4, 2.1), 1, 1.05,
             edgecolor = 'k',
             facecolor = 'blue',
             alpha = 1,
             fill=True, label = 'Model',
             lw=1))
plt.plot(
    (3,4),
    (2.625,2.625),
    c = 'k'
)
plt.gca().add_patch(Rectangle((5, 2.375), 1, .5,
             edgecolor = 'k',
             facecolor = 'yellow',
             alpha = 1,
             fill=True, label = 'Testing Theory',
             lw=1))



plt.gca().add_patch(Rectangle((6, 0), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((6,1.1), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((6, 2.2), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((6, 3.3), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((6, 4.4), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))

plt.gca().add_patch(Rectangle((8, 0.5), 1, 4.4,
             edgecolor = 'k',
             facecolor = 'red',
             alpha = 1,
#              fill=True, label = 'Theory',
             lw=1))
plt.plot(
    (7,8),
    (5.4,4.9),
    c = 'k'
)
plt.plot(
    (7,8),
    (0,0.5),
    c = 'k'
)
plt.xlim(0,9.1)
plt.ylim(0,8)
plt.xticks([]) 
plt.yticks([])
plt.legend(loc = 'upper left')
plt.box(False)
# plt.title('Classical Scientific Approach')

# %%
plt.gca().add_patch(Rectangle((0, 0), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
             fill=True, label = 'Observations',
             lw=1))

plt.gca().add_patch(Rectangle((0,1.1), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((0, 2.2), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((0, 3.3), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((0, 4.4), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
# plt.gca().add_patch(Rectangle((0, 5.5), 1, 1,
#              edgecolor = 'k',
#              facecolor = 'green',
#              alpha = 1,
# #              fill=True, label = 'Observations',
#              lw=1))
# plt.gca().add_patch(Rectangle((0, 6.6), 1, 1,
#              edgecolor = 'k',
#              facecolor = 'green',
#              alpha = 1,
# #              fill=True, label = 'Observations',
#              lw=1))

# plt.gca().add_artist(
#     plt.Circle((2,6), radius=.5,color = 'green',alpha = 1)
# )

plt.gca().add_patch(Rectangle((2, 1.1), 1, 3.2,
             edgecolor = 'k',
             facecolor = 'blue',
             alpha = 1,
             fill=True, label = 'Model',
             lw=1))
plt.plot(
    (1,2),
    (5.4,4.3),
    c = 'k',
    linewidth = 1
)
plt.plot(
    (1,2),
    (0,1.1),
    c = 'k',
    linewidth = 1
)


plt.gca().add_patch(Rectangle((4, 1.1), 1, 3.2,
             edgecolor = 'k',
             facecolor = 'blue',
             alpha = 1,
#              fill=True, label = 'Model',
             lw=1))

plt.gca().add_patch(Rectangle((4, 4.3), 1, 0.575,
             edgecolor = 'k',
             facecolor = 'red',
             alpha = 1,
#              fill=True, label = 'Theory',
             lw=1))
plt.gca().add_patch(Rectangle((4, 0.525), 1, 0.575,
             edgecolor = 'k',
             facecolor = 'red',
             alpha = 1,
             fill=True, label = 'Theory',
             lw=1))
plt.plot(
    (3,4),
    (2.625,2.625),
    c = 'k'
)
plt.plot(
    (5,6),
    (2.625,2.625),
    c = 'orange',
    linewidth = 5
)
plt.plot(
    (5,6),
    (2.625,0.5),
    c = 'orange',
    linewidth = 5
)
plt.plot(
    (5,6),
    (2.625,1.6),
    c = 'orange',
    linewidth = 5
)
plt.plot(
    (5,6),
    (2.625,2.7),
    c = 'orange',
    linewidth = 5
)
plt.plot(
    (5,6),
    (2.625,3.8),
    c = 'orange',
    linewidth = 5
)
plt.plot(
    (5,6),
    (2.625,4.9),
    c = 'orange',
    linewidth = 5
)
# plt.gca().add_patch(Rectangle((5, 2.375), 1, .5,
#              edgecolor = 'k',
#              facecolor = 'yellow',
#              alpha = 1,
# #              fill=True, label = 'Testing Theory',
#              lw=1))



plt.gca().add_patch(Rectangle((6, 0), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((6,1.1), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((6, 2.2), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((6, 3.3), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))
plt.gca().add_patch(Rectangle((6, 4.4), 1, 1,
             edgecolor = 'k',
             facecolor = 'green',
             alpha = 1,
#              fill=True, label = 'Observations',
             lw=1))

plt.gca().add_patch(Rectangle((8, 0.5), 1, 4.4,
             edgecolor = 'k',
             facecolor = 'red',
             alpha = 1,
#              fill=True, label = 'Theory',
             lw=1))
plt.plot(
    (7,8),
    (5.4,4.9),
    c = 'k'
)
plt.plot(
    (7,8),
    (0,0.5),
    c = 'k'
)
plt.xlim(0,9.1)
plt.ylim(0,8)
plt.xticks([]) 
plt.yticks([])
plt.legend(loc = 'upper right')
plt.box(False)
# plt.title('Classical Scientific Approach')
