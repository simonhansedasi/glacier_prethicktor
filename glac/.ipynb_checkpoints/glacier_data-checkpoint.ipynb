# %%
# import sys
# !{sys.executable} -m pip install 
# import gdal
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
# import glacierml as gl
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
print(tf.__version__)

# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# raw_dataset = pd.read_csv("/data/fast0/datasets/glathida-3.1.0/data/T.csv")
raw_dataset = pd.read_csv("~/data/glac/T_models/T.csv")
# raw_dataset = pd.read_csv("~/stuff/coding/glacier/data/T.csv")

dataset = raw_dataset.copy()

#examine data columns
dataset.head()
# Out:
# 2.7.0
#    GlaThiDa_ID POLITICAL_UNIT     GLACIER_NAME GLACIER_DB    GLACIER_ID  \
# 0            1             SE      ISFALLSGLAC        WGI  SE4B000E0006
# 1            2             SE  RABOTS GLACIAER        WGI  SE4B000E1016
# 2            3             SE   STORGLACIAEREN        WGI  SE4B000E0005
# 3            4             US    SOUTH CASCADE        WGI  US2M00264006
# 4            5             CA        ATHABASCA        FOG             7
#
#         LAT        LON  SURVEY_DATE  ELEVATION_DATE  AREA  ...  \
# 0  67.91500   18.56800   19790399.0      19799999.0   1.3  ...
# 1  67.91000   18.49600   19790399.0      19799999.0   4.1  ...
# 2  67.90000   18.57000   19790399.0      19799999.0   3.1  ...
# 3  48.35698 -121.05735   19759999.0      19759999.0   2.0  ...
# 4  52.17540 -117.28400          NaN             NaN   3.8  ...
#
#    SURVEY_METHOD_DETAILS  NUMBER_OF_SURVEY_POINTS  NUMBER_OF_SURVEY_PROFILES  \
# 0                    NaN                      NaN                        NaN
# 1                    NaN                      NaN                       10.0
# 2                    NaN                      NaN                        NaN
# 3                    NaN                      NaN                        NaN
# 4                    NaN                      NaN                        NaN
#
#    TOTAL_LENGTH_OF_SURVEY_PROFILES  INTERPOLATION_METHOD  \
# 0                              NaN                   NaN
# 1                              NaN                   NaN
# 2                              NaN                   NaN
# 3                              NaN                   NaN
# 4                              NaN                   NaN
#
#            INVESTIGATOR      SPONSORING_AGENCY  \
# 0  Schytt V. and others  University of Iceland
# 1  Schytt V. and others  University of Iceland
# 2  Schytt V. and others  University of Iceland
# 3                   NaN                    NaN
# 4                   NaN                    NaN
#
#                                           REFERENCES  DATA_FLAG  REMARKS
# 0                 Björnsson, H., (1981). Geogr. Ann.        NaN      NaN
# 1                 Björnsson, H., (1981). Geogr. Ann.        NaN      NaN
# 2                 Björnsson, H., (1981). Geogr. Ann.        NaN      NaN
# 3  Driedger, C.L., and Kennard, P.M., (1986a). An...        NaN      NaN
# 4  Driedger, C.L., and Kennard, P.M., (1986a). An...        NaN      NaN
#
# [5 rows x 26 columns]

# %%
#drop everything but lat, long, elevation, thickness

# dataset = dataset.drop("GlaThiDa_ID", axis=1)
dataset = dataset.drop("GLACIER_DB", axis=1)
dataset = dataset.drop("POLITICAL_UNIT", axis=1)
dataset = dataset.drop("GLACIER_ID", axis=1)
dataset = dataset.drop("GLACIER_NAME", axis=1)
dataset = dataset.drop("SURVEY_DATE", axis=1)
dataset = dataset.drop("MEAN_THICKNESS_UNCERTAINTY", axis=1)
dataset = dataset.drop("MAXIMUM_THICKNESS", axis=1)
dataset = dataset.drop("MAX_THICKNESS_UNCERTAINTY", axis=1)
dataset = dataset.drop("DATA_FLAG", axis=1)
dataset = dataset.drop("ELEVATION_DATE", axis=1)
dataset = dataset.drop("SPONSORING_AGENCY", axis=1)
dataset = dataset.drop("REMARKS", axis=1)
dataset = dataset.drop("SURVEY_METHOD_DETAILS", axis=1)
dataset = dataset.drop("SURVEY_METHOD", axis=1)
dataset = dataset.drop("NUMBER_OF_SURVEY_POINTS", axis=1)
dataset = dataset.drop("NUMBER_OF_SURVEY_PROFILES", axis=1)
dataset = dataset.drop("TOTAL_LENGTH_OF_SURVEY_PROFILES", axis=1)
dataset = dataset.drop("INTERPOLATION_METHOD", axis=1)
dataset = dataset.drop("INVESTIGATOR", axis=1)
dataset = dataset.drop("REFERENCES", axis=1)

#drop the remaining null pieces from elevation
dataset = dataset.dropna()
dataset.isna().sum()
# Out:
# GlaThiDa_ID                           0
# POLITICAL_UNIT                        0
# GLACIER_NAME                       3634
# GLACIER_DB                          262
# GLACIER_ID                          262
# LAT                                   0
# LON                                   0
# SURVEY_DATE                         149
# ELEVATION_DATE                      485
# AREA                               4152
# MEAN_SLOPE                         4714
# MEAN_THICKNESS                     4641
# MEAN_THICKNESS_UNCERTAINTY         5013
# MAXIMUM_THICKNESS                  4614
# MAX_THICKNESS_UNCERTAINTY          5005
# SURVEY_METHOD                        17
# SURVEY_METHOD_DETAILS              4606
# NUMBER_OF_SURVEY_POINTS             421
# NUMBER_OF_SURVEY_PROFILES          5073
# TOTAL_LENGTH_OF_SURVEY_PROFILES    5000
# INTERPOLATION_METHOD               4955
# INVESTIGATOR                        439
# SPONSORING_AGENCY                   516
# REFERENCES                            2
# DATA_FLAG                          5070
# REMARKS                             250
# dtype: int64

# %%
dataset
# Out:
#       GlaThiDa_ID POLITICAL_UNIT     GLACIER_NAME GLACIER_DB    GLACIER_ID  \
# 0               1             SE      ISFALLSGLAC        WGI  SE4B000E0006
# 1               2             SE  RABOTS GLACIAER        WGI  SE4B000E1016
# 2               3             SE   STORGLACIAEREN        WGI  SE4B000E0005
# 3               4             US    SOUTH CASCADE        WGI  US2M00264006
# 4               5             CA        ATHABASCA        FOG             7
# ...           ...            ...              ...        ...           ...
# 5136         6627             US      MOUNT ADAMS        NaN           NaN
# 5137         6628             US      MOUNT ADAMS        NaN           NaN
# 5138         6629             US      MOUNT ADAMS        NaN           NaN
# 5139         6630             AT     MULLWITZKEES        OTH          6054
# 5140         6631             AT     MULLWITZKEES        OTH          6054
#
#            LAT        LON  SURVEY_DATE  ELEVATION_DATE    AREA  ...  \
# 0     67.91500   18.56800   19790399.0      19799999.0   1.300  ...
# 1     67.91000   18.49600   19790399.0      19799999.0   4.100  ...
# 2     67.90000   18.57000   19790399.0      19799999.0   3.100  ...
# 3     48.35698 -121.05735   19759999.0      19759999.0   2.000  ...
# 4     52.17540 -117.28400          NaN             NaN   3.800  ...
# ...        ...        ...          ...             ...     ...  ...
# 5136  46.20240 -121.49090   19359999.0      19359999.0     NaN  ...
# 5137  46.20240 -121.49090   20020599.0      20020599.0  16.200  ...
# 5138  46.20398 -121.49376   20060799.0      20060799.0     NaN  ...
# 5139  47.08670   12.38000   19989999.0      19989999.0   3.229  ...
# 5140  47.08670   12.38000   20039999.0      20039999.0     NaN  ...
#
#                                   SURVEY_METHOD_DETAILS  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5136                                                NaN
# 5137              Helicopter Electromagnetic Data (HEM)
# 5138  Portable pulseEKKO 100 radar system with a 100...
# 5139  Narod GPR, 4.0 and 6.5MHz, wave velocity in ic...
# 5140  Narod GPR, 4.0 and 6.5MHz, wave velocity in ic...
#
#       NUMBER_OF_SURVEY_POINTS  NUMBER_OF_SURVEY_PROFILES  \
# 0                         NaN                        NaN
# 1                         NaN                       10.0
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 5136                     14.0                        NaN
# 5137                    217.0                        NaN
# 5138                     78.0                        NaN
# 5139                     30.0                        NaN
# 5140                      1.0                        NaN
#
#       TOTAL_LENGTH_OF_SURVEY_PROFILES  INTERPOLATION_METHOD  \
# 0                                 NaN                   NaN
# 1                                 NaN                   NaN
# 2                                 NaN                   NaN
# 3                                 NaN                   NaN
# 4                                 NaN                   NaN
# ...                               ...                   ...
# 5136                              NaN                   NaN
# 5137                              NaN                   NaN
# 5138                              NaN                   NaN
# 5139                              NaN                   OTH
# 5140                              NaN                   NaN
#
#                INVESTIGATOR      SPONSORING_AGENCY  \
# 0      Schytt V. and others  University of Iceland
# 1      Schytt V. and others  University of Iceland
# 2      Schytt V. and others  University of Iceland
# 3                       NaN                    NaN
# 4                       NaN                    NaN
# ...                     ...                    ...
# 5136  Claude Stewart Fowler                    NaN
# 5137          Carol A. Finn                    NaN
# 5138        Slawek Tulaczyk                    NaN
# 5139  Andrea FISCHER et al.                    NaN
# 5140  Andrea FISCHER et al.                    NaN
#
#                                              REFERENCES  DATA_FLAG  \
# 0                    Björnsson, H., (1981). Geogr. Ann.        NaN
# 1                    Björnsson, H., (1981). Geogr. Ann.        NaN
# 2                    Björnsson, H., (1981). Geogr. Ann.        NaN
# 3     Driedger, C.L., and Kennard, P.M., (1986a). An...        NaN
# 4     Driedger, C.L., and Kennard, P.M., (1986a). An...        NaN
# ...                                                 ...        ...
# 5136  C.S. Fowler (1936). The origin of the sulphur ...        NaN
# 5137  Carol A. Finn, Maria Deszcz-Pan, and Paul A. B...        NaN
# 5138  Carol A. Finn, Maria Deszcz-Pan, and Paul A. B...        2.0
# 5139  Fischer, Andrea; Span, Norbert; Kuhn, Michael;...        NaN
# 5140  Fischer, Andrea; Span, Norbert; Kuhn, Michael;...        NaN
#
#                                                 REMARKS
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5136                                                NaN
# 5137  AREA: Danielle J. Sitts, Andrew G. Fountain, a...
# 5138                                                NaN
# 5139  Coordinate from FoG 2015; INTERPOLATION_METHOD...
# 5140  Coordinate from FoG 2015; Outlines/DEM from Au...
#
# [5141 rows x 26 columns]

# %%
len(dataset["GLACIER_NAME"].unique())
# Out:
# 861

# %%
#split the dataset and reserve some to test what was trained.
train_dataset = dataset.sample(frac=0.8, random_state=1)
test_dataset = dataset.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[["LON","LAT", "AREA", "MEAN_SLOPE", "MEAN_THICKNESS"]], diag_kind='kde')

# %%
train_dataset.describe().transpose()
# Out:
#                                   count          mean           std  \
# GlaThiDa_ID                      4113.0  3.928519e+03   1715.839515
# LAT                              4113.0  5.963788e+01     38.834655
# LON                              4113.0 -4.293627e+01     45.500420
# SURVEY_DATE                      3997.0  2.009948e+07  90317.366008
# ELEVATION_DATE                   3738.0  2.010963e+07  76079.704643
# AREA                              788.0  2.529041e+02   1789.121629
# MEAN_SLOPE                        343.0  9.291545e+00      6.085369
# MEAN_THICKNESS                    401.0  7.010474e+01     68.288608
# MEAN_THICKNESS_UNCERTAINTY        106.0  7.386792e+00      6.426983
# MAXIMUM_THICKNESS                 425.0  2.016753e+02    210.479334
# MAX_THICKNESS_UNCERTAINTY         114.0  1.028070e+01      7.330997
# NUMBER_OF_SURVEY_POINTS          3776.0  9.156470e+02   3398.345163
# NUMBER_OF_SURVEY_PROFILES          54.0  1.516667e+01     12.641277
# TOTAL_LENGTH_OF_SURVEY_PROFILES   120.0  5.291362e+01    197.652762
# DATA_FLAG                          53.0  1.283019e+00      0.600556
#
#                                           min           25%           50%  \
# GlaThiDa_ID                      1.000000e+00  2.769000e+03  4.064000e+03
# LAT                             -7.821930e+01  6.629890e+01  7.019090e+01
# LON                             -1.513000e+02 -7.048380e+01 -5.336090e+01
# SURVEY_DATE                      1.936000e+07  2.011041e+07  2.012051e+07
# ELEVATION_DATE                   1.936000e+07  2.011050e+07  2.012052e+07
# AREA                             2.640000e-02  2.100000e+00  1.095900e+01
# MEAN_SLOPE                       0.000000e+00  6.000000e+00  9.000000e+00
# MEAN_THICKNESS                   4.000000e+00  3.300000e+01  5.200000e+01
# MEAN_THICKNESS_UNCERTAINTY       0.000000e+00  3.000000e+00  5.000000e+00
# MAXIMUM_THICKNESS                1.200000e+01  9.700000e+01  1.420000e+02
# MAX_THICKNESS_UNCERTAINTY        2.000000e+00  5.000000e+00  8.000000e+00
# NUMBER_OF_SURVEY_POINTS          1.000000e+00  2.900000e+01  1.090000e+02
# NUMBER_OF_SURVEY_PROFILES        1.000000e+00  6.000000e+00  1.050000e+01
# TOTAL_LENGTH_OF_SURVEY_PROFILES  1.400000e-01  2.985000e+00  1.050000e+01
# DATA_FLAG                        1.000000e+00  1.000000e+00  1.000000e+00
#
#                                           75%           max
# GlaThiDa_ID                      5.328000e+03  6.631000e+03
# LAT                              7.795760e+01  8.296860e+01
# LON                             -2.591620e+01  1.703200e+02
# SURVEY_DATE                      2.014051e+07  2.018073e+07
# ELEVATION_DATE                   2.014051e+07  2.017112e+07
# AREA                             9.952600e+01  4.000000e+04
# MEAN_SLOPE                       1.200000e+01  4.800000e+01
# MEAN_THICKNESS                   7.600000e+01  5.410000e+02
# MEAN_THICKNESS_UNCERTAINTY       1.000000e+01  3.000000e+01
# MAXIMUM_THICKNESS                2.350000e+02  2.500000e+03
# MAX_THICKNESS_UNCERTAINTY        1.475000e+01  3.600000e+01
# NUMBER_OF_SURVEY_POINTS          5.132500e+02  6.126900e+04
# NUMBER_OF_SURVEY_PROFILES        2.100000e+01  6.000000e+01
# TOTAL_LENGTH_OF_SURVEY_PROFILES  2.250000e+01  1.657000e+03
# DATA_FLAG                        1.000000e+00  3.000000e+00

# %%
#separate out features - what will be trained to predict desired attribute
train_features = train_dataset.copy()
test_features = test_dataset.copy()

#define label - attribute training to be picked
train_labels = train_features.pop("MEAN_THICKNESS")
test_labels = test_features.pop("MEAN_THICKNESS")

train_features.describe().transpose()[['mean', 'std']]
# Out:
#                                          mean           std
# GlaThiDa_ID                      3.928519e+03   1715.839515
# LAT                              5.963788e+01     38.834655
# LON                             -4.293627e+01     45.500420
# SURVEY_DATE                      2.009948e+07  90317.366008
# ELEVATION_DATE                   2.010963e+07  76079.704643
# AREA                             2.529041e+02   1789.121629
# MEAN_SLOPE                       9.291545e+00      6.085369
# MEAN_THICKNESS_UNCERTAINTY       7.386792e+00      6.426983
# MAXIMUM_THICKNESS                2.016753e+02    210.479334
# MAX_THICKNESS_UNCERTAINTY        1.028070e+01      7.330997
# NUMBER_OF_SURVEY_POINTS          9.156470e+02   3398.345163
# NUMBER_OF_SURVEY_PROFILES        1.516667e+01     12.641277
# TOTAL_LENGTH_OF_SURVEY_PROFILES  5.291362e+01    197.652762
# DATA_FLAG                        1.283019e+00      0.600556

# %% [markdown]
# # Establish normalization layers

# %%
normalizer = {}
variable_list = ('AREA','LAT','LON','MEAN_SLOPE')
for variable_name in variable_list:

    normalizer[variable_name] = preprocessing.Normalization(input_shape=[1,], axis=None)
    normalizer[variable_name].adapt(np.array(train_features[variable_name]))
    
    
normalizer['ALL'] = preprocessing.Normalization(axis=-1)
normalizer['ALL'].adapt(np.array(train_features))
# Out:
# 2022-03-11 14:04:37.666250: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-11 14:04:37.666295: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (sermeq.ess.washington.edu): /proc/driver/nvidia/version does not exist
# 2022-03-11 14:04:37.666831: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2062872/3866439389.py in <module>
#       8
#       9 normalizer['ALL'] = preprocessing.Normalization(axis=-1)
# ---> 10 normalizer['ALL'].adapt(np.array(train_features))
#
# ~/miniconda3/envs/python-cartopy-f/lib/python3.7/site-packages/keras/engine/base_preprocessing_layer.py in adapt(self, data, batch_size, steps)
#     237         epochs=1,
#     238         steps_per_execution=self._steps_per_execution,
# --> 239         distribute=False)
#     240     self._adapt_function = self.make_adapt_function()
#     241     for _, iterator in data_handler.enumerate_epochs():
#
# ~/miniconda3/envs/python-cartopy-f/lib/python3.7/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1163         use_multiprocessing=use_multiprocessing,
#    1164         distribution_strategy=tf.distribute.get_strategy(),
# -> 1165         model=model)
#    1166
#    1167     strategy = tf.distribute.get_strategy()
#
# ~/miniconda3/envs/python-cartopy-f/lib/python3.7/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     233                **kwargs):
#     234     super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 235     x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     236     sample_weight_modes = broadcast_sample_weight_modes(
#     237         sample_weights, sample_weight_modes)
#
# ~/miniconda3/envs/python-cartopy-f/lib/python3.7/site-packages/keras/engine/data_adapter.py in _process_tensorlike(inputs)
#    1045     return x
#    1046
# -> 1047   inputs = tf.nest.map_structure(_convert_single_tensor, inputs)
#    1048   return tf.__internal__.nest.list_to_tuple(inputs)
#    1049
#
# ~/miniconda3/envs/python-cartopy-f/lib/python3.7/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/miniconda3/envs/python-cartopy-f/lib/python3.7/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/miniconda3/envs/python-cartopy-f/lib/python3.7/site-packages/keras/engine/data_adapter.py in _convert_single_tensor(x)
#    1040       if issubclass(x.dtype.type, np.floating):
#    1041         dtype = backend.floatx()
# -> 1042       return tf.convert_to_tensor(x, dtype=dtype)
#    1043     elif _is_scipy_sparse(x):
#    1044       return _scipy_sparse_to_sparse_tensor(x)
#
# ~/miniconda3/envs/python-cartopy-f/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# ~/miniconda3/envs/python-cartopy-f/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     104       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105   ctx.ensure_initialized()
# --> 106   return ops.EagerTensor(value, ctx.device_name, dtype)
#     107
#     108
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type int).

# %% [markdown]
# # Single variable linear regression functions

# %%
# glacierml

def build_linear_model(normalizer):
    model = tf.keras.Sequential([
        normalizer,
        layers.Dense(1)
    ])

    model.compile(
        optimizer=tf.optimizers.Adam(learning_rate=0.1),
        loss="mean_absolute_error")
    
    return model

def plot_single_model_variable(x, y,feature_name):
    plt.scatter(train_features[feature_name], train_labels, label='Data')
    plt.plot(x, y, color='k', label='Predictions')
    plt.xlabel(feature_name)
    plt.ylabel("Avg Thickness (m)")
#     plt.xlim((0,20))
    plt.legend()
      
def plot_loss(history):
#     plt.subplots(figsize=(10,5))
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    #   plt.ylim([0, 10])
    plt.xlabel('Epoch')
    plt.ylabel('Error')
    plt.legend()
    plt.grid(True)

# %%
test_results = {}
linear_model = {}
linear_history = {}
linear_results = {}

# %% [markdown]
# # Linear regression

# %%
# %%time
variable_list = ('AREA','LAT','LON','MEAN_SLOPE')
for variable_name in variable_list:

    linear_model[variable_name] = build_linear_model(normalizer[variable_name])
    linear_history[variable_name] = linear_model[variable_name].fit(
                                        train_features[variable_name], train_labels,        
                                        epochs=1000,
                                        verbose=0,
                                        validation_split = 0.2)
    
    
    linear_results[variable_name] = linear_model[variable_name].evaluate(
                                        test_features[variable_name],
                                        test_labels, verbose=0)

linear_results

# %%
for variable_name in variable_list:    
    df = pd.DataFrame(linear_history[variable_name].history)
    dfs = df.loc[[df.last_valid_index()]]
    dfs.insert(0, 'Variable', [variable_name])
    
    print(dfs)
    print("")

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
for i, variable_name in enumerate(variable_list):
    ax = plt.subplot(2,2,i+1)
    plt.subplot(2,2,i+1)
    plot_loss(linear_history[variable_name])
    ax.set_title(variable_name)
#     plt.savefig("/home/sa42/notebooks/glac/figs/GTP1_loss.eps")

# %%
# thiswillcrash()

# %% [markdown]
# # Linear regression with multiple inputs

# %%
linear_model = build_linear_model(normalizer['ALL'])

history_full = linear_model.fit(
train_features, train_labels,        
   epochs=1000,
   verbose=0,
   validation_split = 0.2)

test_results["MULTI"] = linear_model.evaluate(
    test_features,
    test_labels, verbose=0)

test_results

# %%
df = pd.DataFrame(history_full.history)
dfs = df.loc[[df.last_valid_index()]]
dfs.insert(0, 'Variable', 'Multi-Variable')
    
print(dfs)

# %%
plot_loss(history_full)
# plt.savefig("/home/sa42/notebooks/glac/figs/GTP1_full_loss.eps")

# %% [markdown]
# # DNN regression

# %% [markdown]
# ## Define regression functions

# %%
def build_dnn_model(norm):
    model = keras.Sequential([
              norm,
              layers.Dense(64, activation='relu'),
              layers.Dense(64, activation='relu'),
              layers.Dense(1) ])

    model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.01))
    
    return model

def dnn_test_results(feature_name):
    dnn_test_results[feature_name] = dnn_model.evaluate(
        test_features[feature_name],
        test_labels, verbose=0)

# %%
test_results = {}
dnn_model = {}
dnn_history = {}
dnn_results = {}

# %%
variable_list = ('AREA','LAT','LON','MEAN_SLOPE')
for variable_name in variable_list:

    dnn_model[variable_name] = build_dnn_model(normalizer[variable_name])
    dnn_history[variable_name] = dnn_model[variable_name].fit(
                                        train_features[variable_name], train_labels,        
                                        epochs=1000,
                                        verbose=0,
                                        validation_split = 0.2)
    dnn_results[variable_name] = dnn_model[variable_name].evaluate(
                                        test_features[variable_name],
                                        test_labels, verbose=0)

dnn_results

# %%
variable_list = ('AREA','LAT','LON','MEAN_SLOPE')

for variable_name in variable_list:    
    df = pd.DataFrame(dnn_history[variable_name].history)
    dfs = df.loc[[df.last_valid_index()]]
    dfs.insert(0, 'Variable', [variable_name])
    
    print(dfs)
    print("")

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
for i, variable_name in enumerate(variable_list):
    plt.subplot(2,2,i+1)
    xmax = np.max(train_features[variable_name])
    xmin = np.min(train_features[variable_name])
    x = tf.linspace(xmin, xmax, 101)
    y = dnn_model[variable_name].predict(x)
    plot_single_model_variable(x,y,variable_name)

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
for i, variable_name in enumerate(variable_list):
    ax = plt.subplot(2,2,i+1)
    plot_loss(dnn_history[variable_name])
    ax.set_title(variable_name)
#     plt.savefig("/home/sa42/notebooks/glac/figs/GTP1_dnn_loss.eps")

# %% [markdown]
# # Full model

# %%
dnn_full_model = build_dnn_model(normalizer['ALL'])

# %%
# %%time
dnn_history_full = dnn_full_model.fit(
    train_features, train_labels,
    validation_split=0.2,
    verbose=0, epochs=1000)

# %%
df = pd.DataFrame(dnn_history_full.history)
dfs = df.loc[[df.last_valid_index()]]
dfs.insert(0, 'Variable', 'Multi-Variable')
    
print(dfs)

# %%
plot_loss(dnn_history_full)
# plt.savefig("/home/sa42/notebooks/glac/figs/GTP1_dnn_full_loss.png")

# %%
y = dnn_full_model.predict(test_features)
plt.plot(test_labels,y,"o")
plt.plot((0,120),(0,120),'-')
plt.xlabel('True Thickness (m)')
plt.ylabel('Model Thickness (m)')
plt.xlim((0,120))
plt.ylim((0,120))
# plt.savefig("/home/sa42/notebooks/glac/figs/GTP1_res.EPS")
