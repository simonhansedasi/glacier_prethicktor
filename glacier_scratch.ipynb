# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# raw_dataset = pd.read_csv("/data/fast0/datasets/glathida-3.1.0/data/T.csv")

T_dataset = pd.read_csv("~/data/glac/T.csv")
TT_dataset = pd.read_csv("~/data/glac/TT.csv")

# %%
TT_dataset = TT_dataset.drop("POLITICAL_UNIT", axis=1)
TT_dataset = TT_dataset.drop("GLACIER_NAME", axis=1)
TT_dataset = TT_dataset.drop("SURVEY_DATE", axis=1)
TT_dataset = TT_dataset.drop("MEAN_THICKNESS_UNCERTAINTY", axis=1)
TT_dataset = TT_dataset.drop("MAXIMUM_THICKNESS", axis=1)
TT_dataset = TT_dataset.drop("MAX_THICKNESS_UNCERTAINTY", axis=1)
TT_dataset = TT_dataset.drop("DATA_FLAG", axis=1)
TT_dataset = TT_dataset.drop("REMARKS", axis=1)

# TT_dataset = TT_dataset.dropna()
TT_dataset.isna().sum()
# Out:
# GlaThiDa_ID        0
# LOWER_BOUND        0
# UPPER_BOUND        0
# AREA               5
# MEAN_SLOPE        12
# MEAN_THICKNESS     0
# dtype: int64

# %%
TT_dataset
# Out:
#      GlaThiDa_ID  LOWER_BOUND  UPPER_BOUND     AREA  MEAN_SLOPE  \
# 0             97         2250         2270  0.01100        12.0
# 1             97         2270         2290  0.01400        15.0
# 2             97         2290         2310  0.01500        18.0
# 3             97         2310         2330  0.02100        25.0
# 4             97         2330         2350  0.03800        18.0
# ..           ...          ...          ...      ...         ...
# 407         2100         4800         4900  0.55900        23.0
# 408         2100         4900         5000  0.54500        26.0
# 409         2100         5000         5100  0.37900        24.0
# 410         2100         5100         5200  0.01600        32.0
# 411         2124         5600         5800  0.51264         NaN
#
#      MEAN_THICKNESS
# 0                43
# 1                36
# 2                29
# 3                22
# 4                19
# ..              ...
# 407              44
# 408              19
# 409               3
# 410               0
# 411              23
#
# [412 rows x 6 columns]

# %%
# T_dataset = T_dataset.drop("GlaThiDa_ID", axis=1)
T_dataset = T_dataset.drop("GLACIER_DB", axis=1)
T_dataset = T_dataset.drop("POLITICAL_UNIT", axis=1)
T_dataset = T_dataset.drop("GLACIER_ID", axis=1)
T_dataset = T_dataset.drop("GLACIER_NAME", axis=1)
T_dataset = T_dataset.drop("NUMBER_OF_SURVEY_POINTS", axis=1)
T_dataset = T_dataset.drop("NUMBER_OF_SURVEY_PROFILES", axis=1)
T_dataset = T_dataset.drop("TOTAL_LENGTH_OF_SURVEY_PROFILES", axis=1)
T_dataset = T_dataset.drop("INTERPOLATION_METHOD", axis=1)
T_dataset = T_dataset.drop("INVESTIGATOR", axis=1)
T_dataset = T_dataset.drop("SPONSORING_AGENCY", axis=1)
T_dataset = T_dataset.drop("ELEVATION_DATE", axis=1)
T_dataset = T_dataset.drop("SURVEY_METHOD_DETAILS", axis=1)
T_dataset = T_dataset.drop("SURVEY_METHOD", axis=1)
T_dataset = T_dataset.drop("SURVEY_DATE", axis=1)
T_dataset = T_dataset.drop("MEAN_THICKNESS", axis=1)
T_dataset = T_dataset.drop("AREA", axis=1)
T_dataset = T_dataset.drop("MEAN_THICKNESS_UNCERTAINTY", axis=1)
T_dataset = T_dataset.drop("MAXIMUM_THICKNESS", axis=1)
T_dataset = T_dataset.drop("MAX_THICKNESS_UNCERTAINTY", axis=1)
T_dataset = T_dataset.drop("DATA_FLAG", axis=1)
T_dataset = T_dataset.drop("REMARKS", axis=1)
T_dataset = T_dataset.drop("REFERENCES", axis=1)
T_dataset = T_dataset.drop("MEAN_SLOPE", axis=1)

#drop the remaining null pieces from elevation
# T_dataset = T_dataset.dropna()
T_dataset.isna().sum()
# Out:
# GlaThiDa_ID    0
# LAT            0
# LON            0
# dtype: int64

# %%
T_dataset
# Out:
#       GlaThiDa_ID       LAT        LON  MEAN_SLOPE
# 0               1  67.91500   18.56800         NaN
# 1               2  67.91000   18.49600         NaN
# 2               3  67.90000   18.57000         NaN
# 3               4  48.35698 -121.05735         NaN
# 4               5  52.17540 -117.28400         NaN
# ...           ...       ...        ...         ...
# 5136         6627  46.20240 -121.49090         NaN
# 5137         6628  46.20240 -121.49090         NaN
# 5138         6629  46.20398 -121.49376         NaN
# 5139         6630  47.08670   12.38000         NaN
# 5140         6631  47.08670   12.38000         NaN
#
# [5141 rows x 4 columns]

# %%
print(TT_dataset["GlaThiDa_ID"].unique())


result = pd.merge(TT_dataset, T_dataset, on=["GlaThiDa_ID"])
# Out:
# [  97  100  104  362  486  487  488  489  490  497 2093 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2073
#  2085 2086 2087 2088 2089 2094 2095 2096 2097 2098 2099 2100 2124]

# %%
TT_plus = pd.merge(TT_dataset, T_dataset, on=["GlaThiDa_ID"])
TT_plus
# Out:
#      GlaThiDa_ID  LOWER_BOUND  UPPER_BOUND     AREA  MEAN_SLOPE  \
# 0             97         2250         2270  0.01100        12.0
# 1             97         2270         2290  0.01400        15.0
# 2             97         2290         2310  0.01500        18.0
# 3             97         2310         2330  0.02100        25.0
# 4             97         2330         2350  0.03800        18.0
# ..           ...          ...          ...      ...         ...
# 407         2100         4800         4900  0.55900        23.0
# 408         2100         4900         5000  0.54500        26.0
# 409         2100         5000         5100  0.37900        24.0
# 410         2100         5100         5200  0.01600        32.0
# 411         2124         5600         5800  0.51264         NaN
#
#      MEAN_THICKNESS     LAT     LON
# 0                43  47.480  13.600
# 1                36  47.480  13.600
# 2                29  47.480  13.600
# 3                22  47.480  13.600
# 4                19  47.480  13.600
# ..              ...     ...     ...
# 407              44  39.237  97.755
# 408              19  39.237  97.755
# 409               3  39.237  97.755
# 410               0  39.237  97.755
# 411              23  -3.056  37.353
#
# [412 rows x 8 columns]

# %%
cols = ["GlaThiDa_ID", "LAT", "LON","MEAN_SLOPE"]
TT_dataset.join(T_dataset.set_index(cols), on=cols)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-f7b6bcb1589d> in <module>
#       1 cols = ["GlaThiDa_ID", "LAT", "LON","MEAN_SLOPE"]
# ----> 2 TT_dataset.join(T_dataset.set_index(cols), on=cols)
#
# ~/.local/lib/python3.9/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9098         5  K5  A5  NaN
#    9099         """
# -> 9100         return self._join_compat(
#    9101             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9102         )
#
# ~/.local/lib/python3.9/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9129                     sort=sort,
#    9130                 )
# -> 9131             return merge(
#    9132                 self,
#    9133                 other,
#
# ~/.local/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     103     validate: str | None = None,
#     104 ) -> DataFrame:
# --> 105     op = _MergeOperation(
#     106         left,
#     107         right,
#
# ~/.local/lib/python3.9/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     696             self.right_join_keys,
#     697             self.join_names,
# --> 698         ) = self._get_merge_keys()
#     699
#     700         # validate the merge keys dtypes. We may need to coerce
#
# ~/.local/lib/python3.9/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1118                     join_names.append(None)
#    1119                 else:
# -> 1120                     left_keys.append(left._get_label_or_level_values(k))
#    1121                     join_names.append(k)
#    1122             if isinstance(self.right.index, MultiIndex):
#
# ~/.local/lib/python3.9/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'LAT'

# %%
TT_dataset["LON"] = np.nan
TT_dataset["LAT"] = np.nan
TT_dataset
# Out:
#      GlaThiDa_ID  LOWER_BOUND  UPPER_BOUND     AREA  MEAN_SLOPE  \
# 0             97         2250         2270  0.01100        12.0
# 1             97         2270         2290  0.01400        15.0
# 2             97         2290         2310  0.01500        18.0
# 3             97         2310         2330  0.02100        25.0
# 4             97         2330         2350  0.03800        18.0
# ..           ...          ...          ...      ...         ...
# 407         2100         4800         4900  0.55900        23.0
# 408         2100         4900         5000  0.54500        26.0
# 409         2100         5000         5100  0.37900        24.0
# 410         2100         5100         5200  0.01600        32.0
# 411         2124         5600         5800  0.51264         NaN
#
#      MEAN_THICKNESS  LON  LAT
# 0                43  NaN  NaN
# 1                36  NaN  NaN
# 2                29  NaN  NaN
# 3                22  NaN  NaN
# 4                19  NaN  NaN
# ..              ...  ...  ...
# 407              44  NaN  NaN
# 408              19  NaN  NaN
# 409               3  NaN  NaN
# 410               0  NaN  NaN
# 411              23  NaN  NaN
#
# [412 rows x 8 columns]

# %%
for row in TT_dataset:
    if TT_dataset["GlaThiDa_ID"] == T_dataset["GlaThiDa_ID"]:
        LAT[row] = T_dataset["GlaThiDa_ID"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-159a3d797f94> in <module>
#       1 for row in TT_dataset:
# ----> 2     if TT_dataset["GlaThiDa_ID"] == T_dataset["GlaThiDa_ID"]:
#       3         LAT[row] = T_dataset["GlaThiDa_ID"]
#
# ~/.local/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/.local/lib/python3.9/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# ~/.local/lib/python3.9/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5494
#    5495         if isinstance(other, Series) and not self._indexed_same(other):
# -> 5496             raise ValueError("Can only compare identically-labeled Series objects")
#    5497
#    5498         lvalues = self._values
#
# ValueError: Can only compare identically-labeled Series objects

# %%
TT_dataset = T_dataset.join(TT_dataset.set_index("GlaThiDa_ID"), on='GlaThiDa_ID')
print (TT_dataset)

# %%
ttpp = pd.merge(TT_dataset, T_dataset[["GlaThiDa_ID"]], left_on="LAT", right_on="LON", how="left")

# %%
for row in TT_dataset:
    if TT_dataset["GlaThiDa_ID"] == T_dataset["GlaThiDa_ID"]:
        T_dataset["LON"] == TT_dataset["LON"]
        
    if TT_dataset["GlaThiDa_ID"] == T_dataset["GlaThiDa_ID"]:
        T_dataset["LAT"] == TT_dataset["LAT"]

# %%
for i in TT_dataset:
    if TT_dataset["GlaThiDa_ID"] == T_dataset["GlaThiDa_ID"]:
        T_dataset["LON"] == TT_dataset["LON"]

# %%
TT_dataset.join(T_dataset, lsuffix='_caller', rsuffix='_other')

# %%
for each row in ttp

# %%
TT_dataset
